# %%
import pandas as pd
import yfinance as yf
import datetime 

start = '2011-01-01'
end = '2024-01-01'

ts = yf.download('TSLA' ,start=start, end=end)
print (ts)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03    1.789333    1.800000    1.726667    1.774667    1.774667
# 2011-01-04    1.777333    1.796667    1.734667    1.778000    1.778000
# 2011-01-05    1.765333    1.793333    1.746000    1.788667    1.788667
# 2011-01-06    1.788667    1.866667    1.787333    1.858667    1.858667
# 2011-01-07    1.866667    1.905333    1.860000    1.882667    1.882667
# ...                ...         ...         ...         ...         ...
# 2023-12-22  256.760010  258.220001  251.369995  252.539993  252.539993
# 2023-12-26  254.490005  257.970001  252.910004  256.609985  256.609985
# 2023-12-27  258.350006  263.339996  257.519989  261.440002  261.440002
# 2023-12-28  263.660004  265.130005  252.710007  253.179993  253.179993
# 2023-12-29  255.100006  255.190002  247.429993  248.479996  248.479996
#
#                Volume
# Date
# ...

# %% [markdown]
# # Description of data

# %%
ts.head
# Out:
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03    1.789333    1.800000    1.726667    1.774667    1.774667
# 2011-01-04    1.777333    1.796667    1.734667    1.778000    1.778000
# 2011-01-05    1.765333    1.793333    1.746000    1.788667    1.788667
# 2011-01-06    1.788667    1.866667    1.787333    1.858667    1.858667
# 2011-01-07    1.866667    1.905333    1.860000    1.882667    1.882667
# ...                ...         ...         ...         ...         ...
# 2023-12-22  256.760010  258.220001  251.369995  252.539993  252.539993
# 2023-12-26  254.490005  257.970001  252.910004  256.609985  256.609985
# 2023-12-27  258.350006  263.339996  257.519989  261.440002  261.440002
# 2023-12-28  263.660004  265.130005  252.710007  253.179993  253.179993
# 2023-12-29  255.100006  255.190002  247.429993  248.479996  248.479996
#
#                Volume
# Date
# 2011-01-03   19245000
# 2011-01-04   17811000
# ...

# %%
ts.tail
# Out:
# <bound method NDFrame.tail of                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03    1.789333    1.800000    1.726667    1.774667    1.774667
# 2011-01-04    1.777333    1.796667    1.734667    1.778000    1.778000
# 2011-01-05    1.765333    1.793333    1.746000    1.788667    1.788667
# 2011-01-06    1.788667    1.866667    1.787333    1.858667    1.858667
# 2011-01-07    1.866667    1.905333    1.860000    1.882667    1.882667
# ...                ...         ...         ...         ...         ...
# 2023-12-22  256.760010  258.220001  251.369995  252.539993  252.539993
# 2023-12-26  254.490005  257.970001  252.910004  256.609985  256.609985
# 2023-12-27  258.350006  263.339996  257.519989  261.440002  261.440002
# 2023-12-28  263.660004  265.130005  252.710007  253.179993  253.179993
# 2023-12-29  255.100006  255.190002  247.429993  248.479996  248.479996
#
#                Volume
# Date
# 2011-01-03   19245000
# 2011-01-04   17811000
# ...

# %%
ts.shape
# Out:
# (3270, 6)

# %%
ts.size
# Out:
# 19620

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3270 entries, 2011-01-03 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3270 non-null   float64
#  1   High       3270 non-null   float64
#  2   Low        3270 non-null   float64
#  3   Close      3270 non-null   float64
#  4   Adj Close  3270 non-null   float64
#  5   Volume     3270 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 178.8 KB

# %%
ts.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
ts.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3270.000000  3270.000000  3270.000000  3270.000000  3270.000000
# mean     73.234467    74.848889    71.495915    73.214106    73.214106
# std     102.605700   104.895721   100.085427   102.525614   102.525614
# min       1.452000     1.484667     1.407333     1.455333     1.455333
# 25%      12.555000    12.800000    12.275333    12.573500    12.573500
# 50%      17.389999    17.634334    17.051666    17.389334    17.389334
# 75%     134.857498   136.667496   127.264999   134.085831   134.085831
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.270000e+03
# mean   9.971839e+07
# std    7.987937e+07
# min    3.594000e+06
# 25%    5.019982e+07
# 50%    8.388000e+07
# 75%    1.257245e+08
# max    9.140820e+08

# %%
ts[ts.High>= 411]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-04  411.470001  414.496674  405.666656  409.970001  409.970001
# 2021-11-05  409.333344  413.290009  402.666656  407.363342  407.363342
#
#               Volume
# Date
# 2021-11-04  76192200
# 2021-11-05  64886400

# %%
ts[ts.Low<= 1.5]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2011-01-20  1.602000  1.630000  1.491333  1.508000   1.508000  34198500
# 2011-02-22  1.525333  1.533333  1.452000  1.458000   1.458000  30969000
# 2011-02-23  1.478667  1.500000  1.407333  1.455333   1.455333  24084000
# 2011-02-24  1.452000  1.505333  1.433333  1.502000   1.502000  15829500
# 2011-03-15  1.480000  1.530667  1.453333  1.530000   1.530000  19782000
# 2011-03-22  1.515333  1.524000  1.466667  1.479333   1.479333   8743500
# 2011-03-23  1.474000  1.484667  1.451333  1.480667   1.480667   6342000
# 2011-03-24  1.476000  1.492000  1.465333  1.488667   1.488667   6933000
# 2011-03-25  1.495333  1.533333  1.493333  1.516667   1.516667   8520000
# 2011-08-19  1.590667  1.614667  1.466667  1.486667   1.486667  20629500
# 2011-08-22  1.540667  1.586667  1.445333  1.463333   1.463333  14791500
# 2011-08-23  1.462000  1.540667  1.433333  1.530667   1.530667  13035000
# ...

# %%
ts[ts.Open>= 411]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-11-04  411.470001  414.496674  405.666656  409.970001  409.970001
#
#               Volume
# Date
# 2021-11-04  76192200

# %%
ts[ts.Open<= 1.5]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2011-02-23  1.478667  1.500000  1.407333  1.455333   1.455333  24084000
# 2011-02-24  1.452000  1.505333  1.433333  1.502000   1.502000  15829500
# 2011-03-15  1.480000  1.530667  1.453333  1.530000   1.530000  19782000
# 2011-03-23  1.474000  1.484667  1.451333  1.480667   1.480667   6342000
# 2011-03-24  1.476000  1.492000  1.465333  1.488667   1.488667   6933000
# 2011-03-25  1.495333  1.533333  1.493333  1.516667   1.516667   8520000
# 2011-08-23  1.462000  1.540667  1.433333  1.530667   1.530667  13035000
# 2011-09-06  1.500000  1.546667  1.486000  1.529333   1.529333  12147000
# 2011-09-12  1.500000  1.554000  1.496667  1.525333   1.525333   8499000

# %% [markdown]
# ## Visualizing the data
# Corelation

# %%
ts.corr(method='pearson', min_periods=1)
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999725  0.999617  0.999208   0.999208  0.082370
# High       0.999725  1.000000  0.999625  0.999644   0.999644  0.086007
# Low        0.999617  0.999625  1.000000  0.999681   0.999681  0.079020
# Close      0.999208  0.999644  0.999681  1.000000   1.000000  0.083327
# Adj Close  0.999208  0.999644  0.999681  1.000000   1.000000  0.083327
# Volume     0.082370  0.086007  0.079020  0.083327   0.083327  1.000000

# %%
import seaborn as sns
sns.heatmap(ts.corr(),annot=True)
# Out:
# C:\Users\Nachi\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# <AxesSubplot:>

# %% [markdown]
# # Perfect Correlation Among Price Columns:
# The columns Open, High, Low, Close, and Adj Close all have a perfect correlation of 1 with each other. This indicates a perfect linear relationship among these price-related columns.
#
# # Volume Correlation:
# The Volume column shows a very low correlation (around 0.08) with all the price-related columns (Open, High, Low, Close, Adj Close). This low correlation indicates that the trading volume does not have a strong linear relationship with the stock prices.

# %% [markdown]
# # Now time serier Analysis Where track the price over specific time period

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
from matplotlib import style

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-03', '2011-01-04', '2011-01-05', '2011-01-06',
#                '2011-01-07', '2011-01-10', '2011-01-11', '2011-01-12',
#                '2011-01-13', '2011-01-14',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', length=3270, freq=None)

# %%
pip install numpy==1.22.0
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Nachi\\anaconda3\\Lib\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
import numpy as np

# Convert to numpy array
adj_close_array = ts['Adj Close'].values

# Example of multi-dimensional indexing
indexed_array = adj_close_array[:, None]

# Now you can use indexed_array in further operations
print(indexed_array)
# Out:
# [[243.25666809]
#  [245.03666687]
#  [251.99333191]
#  [272.01333618]
#  [293.33999634]
#  [270.39666748]
#  [283.14666748]
#  [284.80334473]
#  [281.66665649]
#  [275.38665771]
#  [281.5166626 ]
#  [283.4833374 ]
#  [281.66333008]
#  [282.21331787]
#  [293.6000061 ]
#  [294.36334229]
#  [288.05334473]
#  [278.47665405]
#  [264.51000977]
#  [279.93667603]
#  [290.92999268]
#  [284.89666748]
#  [283.32998657]
#  [284.07666016]
#  [287.80667114]
#  [283.15332031]
#  [268.27334595]
#  [270.55334473]
#  [272.04000854]
#  [265.40667725]
#  [266.04998779]
#  [262.45999146]
#  [260.43331909]
#  [238.16667175]
#  [232.94667053]
#  [247.33999634]
#  [227.40666199]
#  [225.16667175]
#  [239.47666931]
#  [228.81333923]
#  [217.7333374 ]
#  [207.14666748]
#  [199.31666565]
#  [187.66667175]
#  [224.52667236]
#  [222.68666077]
#  [233.19999695]
#  [231.24333191]
#  [235.97999573]
#  [225.62666321]
#  [233.93666077]
#  [217.72000122]
#  [218.28999329]
#  [223.33332825]
#  [220.72000122]
# ...

# %%
dates = ts.index.values
adj_close_prices = ts['Adj Close'].values

plt.plot(dates, adj_close_prices)
plt.title('TESLA')
plt.ylabel('Adjusted Closing Price')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np

# Convert to numpy array
adj_close_array = ts['Adj Close'].values

# Example of multi-dimensional indexing
indexed_array = adj_close_array[:, None]

# Now you can use indexed_array in further operations
print(indexed_array)
# Out:
# [[  1.77466702]
#  [  1.778     ]
#  [  1.78866696]
#  ...
#  [261.44000244]
#  [253.17999268]
#  [248.47999573]]

# %%
dates = ts.index.values
adj_close_prices = ts['Adj Close'].values

plt.plot(dates, adj_close_prices)
plt.title('TESLA')
plt.ylabel('Adjusted Closing Price')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np

# Convert to numpy array
adj_close_array = ts['Adj Close'].values

# Example of multi-dimensional indexing
indexed_array = adj_close_array[:, None]

# Now you can use indexed_array in further operations
print(indexed_array)
# Out:
# [[243.25666809]
#  [245.03666687]
#  [251.99333191]
#  [272.01333618]
#  [293.33999634]
#  [270.39666748]
#  [283.14666748]
#  [284.80334473]
#  [281.66665649]
#  [275.38665771]
#  [281.5166626 ]
#  [283.4833374 ]
#  [281.66333008]
#  [282.21331787]
#  [293.6000061 ]
#  [294.36334229]
#  [288.05334473]
#  [278.47665405]
#  [264.51000977]
#  [279.93667603]
#  [290.92999268]
#  [284.89666748]
#  [283.32998657]
#  [284.07666016]
#  [287.80667114]
#  [283.15332031]
#  [268.27334595]
#  [270.55334473]
#  [272.04000854]
#  [265.40667725]
#  [266.04998779]
#  [262.45999146]
#  [260.43331909]
#  [238.16667175]
#  [232.94667053]
#  [247.33999634]
#  [227.40666199]
#  [225.16667175]
#  [239.47666931]
#  [228.81333923]
#  [217.7333374 ]
#  [207.14666748]
#  [199.31666565]
#  [187.66667175]
#  [224.52667236]
#  [222.68666077]
#  [233.19999695]
#  [231.24333191]
#  [235.97999573]
#  [225.62666321]
#  [233.93666077]
#  [217.72000122]
#  [218.28999329]
#  [223.33332825]
#  [220.72000122]
# ...

# %%
ts = ts.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-12-31')]

# Convert the index and 'Adj Close' series to numpy arrays
dates = ts.index.values
adj_close_prices = ts['Adj Close'].values


plt.plot(dates, adj_close_prices)
plt.title('TESLA')
plt.ylabel('Adjusted Closing Price')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
Monthly_ts = ts.resample('4M').mean()
Monthly_ts
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-31  275.725791  281.719997  270.357716  276.258947  276.258947
# 2021-05-31  231.374297  236.277630  224.842410  230.661125  230.661125
# 2021-09-30  228.345853  231.871472  225.049806  228.613994  228.613994
# 2022-01-31  334.779687  342.762552  326.788801  335.389687  335.389687
#
#                   Volume
# Date
# 2021-01-31  1.114255e+08
# 2021-05-31  1.000853e+08
# 2021-09-30  6.069307e+07
# 2022-01-31  7.912978e+07

# %%
Monthly_Tesla = ts.resample('4M').mean()
plt.scatter(Monthly_Tesla.index, Monthly_Tesla['Adj Close'])
plt.title('TESLA')
plt.ylabel('Adjusted Closing Price')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
Tesla = ts.loc[pd.Timestamp('2021-01-15'):pd.Timestamp('2021-12-31')]
Tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-15  284.000000  286.633331  273.033325  275.386658  275.386658
# 2021-01-19  279.266663  283.333344  277.666656  281.516663  281.516663
# 2021-01-20  286.246674  286.500000  279.093323  283.483337  283.483337
# 2021-01-21  285.000000  285.239990  280.473328  281.663330  281.663330
# 2021-01-22  278.103333  282.666656  276.206665  282.213318  282.213318
# ...                ...         ...         ...         ...         ...
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#                Volume
# Date
# 2021-01-15  116332800
# 2021-01-19   76101000
# 2021-01-20   76997700
# ...

# %%
weekly_ts = ts.resample('W').mean()
weekly_ts.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-10  255.682669  264.053995  253.271997  261.128000  261.128000
# 2021-01-17  281.903333  287.053333  274.720667  279.079999  279.079999
# 2021-01-24  282.154167  284.434998  278.359993  282.219162  282.219162
# 2021-01-31  284.448669  291.880664  276.678662  283.800671  283.800671
# 2021-02-07  282.399329  288.123328  277.547339  284.633997  284.633997
#
#                  Volume
# Date
# 2021-01-10  151282680.0
# 2021-01-17  125357220.0
# 2021-01-24   68715375.0
# 2021-01-31   91804680.0
# 2021-02-07   61476240.0

# %%
import numpy as np

# Convert to numpy array
adj_close_array = ts['Adj Close'].values

# Example of multi-dimensional indexing
indexed_array = adj_close_array[:, None]

# Now you can use indexed_array in further operations
print(indexed_array)
# Out:
# [[243.25666809]
#  [245.03666687]
#  [251.99333191]
#  [272.01333618]
#  [293.33999634]
#  [270.39666748]
#  [283.14666748]
#  [284.80334473]
#  [281.66665649]
#  [275.38665771]
#  [281.5166626 ]
#  [283.4833374 ]
#  [281.66333008]
#  [282.21331787]
#  [293.6000061 ]
#  [294.36334229]
#  [288.05334473]
#  [278.47665405]
#  [264.51000977]
#  [279.93667603]
#  [290.92999268]
#  [284.89666748]
#  [283.32998657]
#  [284.07666016]
#  [287.80667114]
#  [283.15332031]
#  [268.27334595]
#  [270.55334473]
#  [272.04000854]
#  [265.40667725]
#  [266.04998779]
#  [262.45999146]
#  [260.43331909]
#  [238.16667175]
#  [232.94667053]
#  [247.33999634]
#  [227.40666199]
#  [225.16667175]
#  [239.47666931]
#  [228.81333923]
#  [217.7333374 ]
#  [207.14666748]
#  [199.31666565]
#  [187.66667175]
#  [224.52667236]
#  [222.68666077]
#  [233.19999695]
#  [231.24333191]
#  [235.97999573]
#  [225.62666321]
#  [233.93666077]
#  [217.72000122]
#  [218.28999329]
#  [223.33332825]
#  [220.72000122]
# ...

# %%
# Convert the index and 'Adj Close' series to numpy arrays
dates = ts.index.values
adj_close_prices = ts['Adj Close'].values
plt.plot(dates, adj_close_prices)
plt.title('Tesla')
plt.ylabel('Adjusted Closing Price')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
daily_close_Tesla =ts[['Adj Close']]
#Daily returns
daily_pct_change_Tesla = daily_close_Tesla.pct_change()
daily_pct_change_Tesla
# Out:
#             Adj Close
# Date
# 2021-01-04        NaN
# 2021-01-05   0.007317
# 2021-01-06   0.028390
# 2021-01-07   0.079447
# 2021-01-08   0.078403
# ...               ...
# 2021-12-27   0.025248
# 2021-12-28  -0.005000
# 2021-12-29  -0.002095
# 2021-12-30  -0.014592
# 2021-12-31  -0.012669
#
# [252 rows x 1 columns]

# %%
daily_pct_change_Tesla.isnull().sum()
# Out:
# Adj Close    1
# dtype: int64

# %%
daily_pct_change_Tesla.fillna(0, inplace=True)
daily_pct_change_Tesla.head()
# Out:
#             Adj Close
# Date
# 2021-01-04   0.000000
# 2021-01-05   0.007317
# 2021-01-06   0.028390
# 2021-01-07   0.079447
# 2021-01-08   0.078403

# %%
daily_pct_change_Tesla.hist(bins=50)
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
# Set up the matplotlib figure
f, axes = plt.subplots( figsize=(7, 5))
# Plot a simple histogram with binsize determined automatically
sns.distplot(daily_pct_change_Tesla['Adj Close'], color="b", axlabel='Tesla');
# Out:
# C:\Users\Nachi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-6626cc741a5f> in <module>
#       2 f, axes = plt.subplots( figsize=(7, 5))
#       3 # Plot a simple histogram with binsize determined automatically
# ----> 4 sns.distplot(daily_pct_change_Tesla['Adj Close'], color="b", axlabel='Tesla');
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2623     if kde:
# ...

# %% [markdown]
# ## Analysis Using 44 and 100 Days Moving Average

# %%
ts = ts.loc[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-12-31')]

# Calculate moving averages
ts['44'] = ts['Adj Close'].rolling(window=44).mean()
ts['150'] = ts['Adj Close'].rolling(window=100).mean()

# Convert the index and 'Adj Close' series to numpy arrays
dates = ts.index.values
adj_close_prices = ts['Adj Close'].values
ma_44 = ts['44'].values
ma_150 = ts['150'].values

# Plotting the data using numpy arrays
plt.figure(figsize=(10, 6))
plt.plot(dates, adj_close_prices, label='Adj Close')
plt.plot(dates, ma_44, label='44 Days MA')
plt.plot(dates, ma_150, label='100 Days MA')
plt.title('Tesla')
plt.ylabel('Adjusted Closing Price')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.grid(True)
plt.xticks(rotation=90)
plt.legend()
plt.show()
